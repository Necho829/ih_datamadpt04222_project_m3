# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# %%
engine = create_engine('sqlite:///db/diamonds_m2.db')

# %%
df = pd.read_sql_query("SELECT * FROM diamonds_dimensions", engine)
#df = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", connection)
df
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z
# 0      6.79  4.25
# ...

# %%
query1= "SELECT * FROM diamonds_dimensions"
df_dimensions = pd.read_sql_query(query1, connection)
df_dimensions
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\miniconda32\envs\Proyect2\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# OperationalError: no such table: diamonds_dimensions
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5332/2872376535.py in <module>
#       1 query1= "SELECT * FROM diamonds_dimensions"
# ----> 2 df_dimensions = pd.read_sql_query(query1, connection)
#       3 df_dimensions
#
# ~\miniconda32\envs\Proyect2\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     441         parse_dates=parse_dates,
# ...
